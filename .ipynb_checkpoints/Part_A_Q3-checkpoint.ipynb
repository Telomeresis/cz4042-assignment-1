# %%
import math
import tensorflow as tf
import numpy as np
import pylab as plt
import pandas as pd

tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
# Set compatibility mode
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# Set pandas display option
pd.options.display.float_format = "{:,.4f}".format 

# RTX ON
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# scale data
def scale(X, X_min, X_max):
    return (X - X_min)/(X_max-X_min)

# %%
NUM_FEATURES = 21
NUM_CLASSES = 3

hidden_units = [5,10,15,20,25]
learning_rate = 0.01
beta = 10**-6
batch_size = 16
no_folds = 5

epochs = 2000
seed = 10
np.random.seed(seed)

# %%
#read data
data_input = np.genfromtxt('ctg_data_cleaned.csv', delimiter= ',')
data_X, data_Y = data_input[1:, :21], data_input[1:,-1].astype(int)
dataX = scale(data_X, np.min(data_X, axis=0), np.max(data_X, axis=0)) #Scaled X

#Defining the size of training set and data set
dataset_size = len(dataX)
train_size = int(0.7 * dataset_size)
test_size = dataset_size - train_size

#Shuffle the data before splitting to train test set
#Data belongings to the same class are usually cluster together in the dataset, we want to shuffle them
idx = np.arange(dataset_size)
np.random.shuffle(idx)
dataX = dataX[idx]
data_Y = data_Y[idx]
dataY = np.zeros((data_Y.shape[0], NUM_CLASSES))
dataY[np.arange(data_Y.shape[0]), data_Y-1] = 1 #one hot matrix

#Split the training and testing set
trainX = dataX[:train_size]
trainY = dataY[:train_size]

testX = dataX[train_size:]
testY = dataY[train_size:]

# %%
# Create the model
x = tf.placeholder(tf.float32, [None, NUM_FEATURES])
y_ = tf.placeholder(tf.float32, [None, NUM_CLASSES])

#Build the graph for the neural network

def ffn(x, hidden_units):
    global w1,b1,h1,w2,b2
    w1 = tf.Variable(tf.truncated_normal([NUM_FEATURES, hidden_units], stddev=1.0/math.sqrt(float(NUM_FEATURES))), name='weights')
    b1 = tf.Variable(tf.zeros([hidden_units]),name='biases')
    h1 = tf.nn.relu(tf.matmul(x, w1) + b1) #Hidden layer with relu activation
    
    w2 = tf.Variable(tf.truncated_normal([hidden_units, NUM_CLASSES], stddev=1.0/math.sqrt(float(hidden_units))), name='weights')
    b2 = tf.Variable(tf.zeros([NUM_CLASSES]),name='biases')
    u = tf.matmul(h1, w2) + b2  #logits=u
    return u

# %%
N = train_size #70% of the dataset
Nf = N//no_folds

cross_validation_acc =[]
x_validation_acc = np.zeros((no_folds, epochs))

for no_hidden in hidden_units:
  
  u = ffn(x,no_hidden)
  
  #Cross-entropy
  cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_, logits=u)

  #Regularization
  regularization = tf.nn.l2_loss(w1) + tf.nn.l2_loss(w2)

  #Regularized loss
  loss = tf.reduce_mean(cross_entropy + beta*regularization)
  
  #Defining the optimiser
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)

  # Create a variable to track the global step
  global_step = tf.Variable(0, name='global_step', trainable=False)

  # Use the optimizer to apply the gradients that minimize the loss
  # (and also increment the global step counter) as a single training step.
  train_op = optimizer.minimize(loss, global_step=global_step)
  
  #Evaluate the accuracy and error
  correct_prediction = tf.cast(tf.equal(tf.argmax(u, 1), tf.argmax(y_, 1)), tf.float32)
  accuracy = tf.reduce_mean(correct_prediction)
  error = tf.reduce_sum(tf.cast(tf.not_equal(tf.argmax(u, axis=1), tf.argmax(y_, axis=1)), dtype=tf.int32))

  validation_acc = np.zeros(no_folds*epochs).reshape(no_folds, epochs)
  ending_validation_acc = []


  for fold in range(no_folds):

    startingIndex , endingIndex = fold*Nf, (fold+1)*Nf
    #Dataset is divided to 70:30 ratio for training and testing
    #The 70%  will go through the 5-fold cross validation
    #For each round, 4 folds will be use for training and 1 fold will be used for validation
    trainX_validate , trainY_validate = trainX[startingIndex:endingIndex], trainY[startingIndex:endingIndex]
    trainX_train = np.append(trainX[:startingIndex],trainX[endingIndex:],axis=0)
    trainY_train = np.append(trainY[:startingIndex],trainY[endingIndex:],axis=0)

#Running the session
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

for i in range(epochs):

for start, end in zip(range(0, N, batch_size), range(batch_size, N, batch_size)): #Want to use all trainX dataset
    train_op.run(feed_dict={x: trainX_train[start:end], y_: trainY_train[start:end]})

#Calculate validation acc and record it for graph plotting with against epochs
validation_acc[fold][i]= accuracy.eval(feed_dict={x: trainX_validate, y_: trainY_validate})
if i == 0 or (i+1)%1000 == 0:
    print('no_hidden {} fold {} iter {}: Validation accuracy {}'.format(no_hidden, fold+1 ,i+1, validation_acc[fold][i]))

print()

#Final validation accuracy at end of epochs
ending_validation_acc.append(accuracy.eval(feed_dict={x: trainX_validate, y_: trainY_validate}))

    # plot learning curves

    plt.figure()
    plt.title('Validation Accuracy vs. epochs')
    plt.xlabel('epochs')
    plt.ylabel('validation accuracy')
    plt.plot(range(epochs), validation_acc[0],'b',label='fold 1')
    plt.plot(range(epochs), validation_acc[1],'g',label='fold 2')
    plt.plot(range(epochs), validation_acc[2],'r',label='fold 3')
    plt.plot(range(epochs), validation_acc[3],'c',label='fold 4')
    plt.plot(range(epochs), validation_acc[4],'m',label='fold 5')
    plt.legend(loc='best')
    plt.show()

    plt.figure()
    plt.title('Cross-Validation Accuracy vs. epochs')
    plt.xlabel('epochs')
    plt.ylabel('cross-validation accuracy')
    plt.plot(range(epochs), np.mean(validation_acc, axis=0) ,'b',label='cross validation accuracy')
    plt.legend(loc='best')
    plt.show()
  
    if no_hidden == 5:
        x_validation_acc[0] = np.mean(validation_acc, axis=0)
    elif no_hidden == 10:
        x_validation_acc[1] = np.mean(validation_acc, axis=0)
    elif no_hidden == 15:
        x_validation_acc[2] = np.mean(validation_acc, axis=0)
    elif no_hidden == 20:
        x_validation_acc[3] = np.mean(validation_acc, axis=0)
    elif no_hidden == 25:
        x_validation_acc[4] = np.mean(validation_acc, axis=0)

    print("For hidden {} , Ending validation accuracy for each fold: {}".format(no_hidden,ending_validation_acc))
    cv_acc = np.mean(np.array(ending_validation_acc),axis = 0)
    print("Cross Validation Accuracy {}".format(cv_acc))
    print()
    cross_validation_acc.append(cv_acc)

print("Cross Validation accuracy for each no_hidden: {}".format(cross_validation_acc))
# Out:
# no_hidden 5 fold 1 iter 1: Validation accuracy 0.7946127653121948
# no_hidden 5 fold 1 iter 1000: Validation accuracy 0.8956229090690613
# no_hidden 5 fold 1 iter 2000: Validation accuracy 0.8956229090690613
#
# no_hidden 5 fold 2 iter 1: Validation accuracy 0.7575757503509521
# no_hidden 5 fold 2 iter 1000: Validation accuracy 0.8989899158477783
# no_hidden 5 fold 2 iter 2000: Validation accuracy 0.9057239294052124
#
# no_hidden 5 fold 3 iter 1: Validation accuracy 0.7979797720909119
# no_hidden 5 fold 3 iter 1000: Validation accuracy 0.9191918969154358
# no_hidden 5 fold 3 iter 2000: Validation accuracy 0.9158248901367188
#
# no_hidden 5 fold 4 iter 1: Validation accuracy 0.744107723236084
# no_hidden 5 fold 4 iter 1000: Validation accuracy 0.8417508602142334
# no_hidden 5 fold 4 iter 2000: Validation accuracy 0.8518518805503845
#
# no_hidden 5 fold 5 iter 1: Validation accuracy 0.7845118045806885
# no_hidden 5 fold 5 iter 1000: Validation accuracy 0.9023569226264954
# no_hidden 5 fold 5 iter 2000: Validation accuracy 0.9023569226264954
# For hidden 5 , Ending validation accuracy for each fold: [0.8956229, 0.9057239, 0.9158249, 0.8518519, 0.9023569]
# Cross Validation Accuracy 0.8942761421203613
#
# no_hidden 10 fold 1 iter 1: Validation accuracy 0.7946127653121948
# no_hidden 10 fold 1 iter 1000: Validation accuracy 0.8888888955116272
# no_hidden 10 fold 1 iter 2000: Validation accuracy 0.8989899158477783
#
# no_hidden 10 fold 2 iter 1: Validation accuracy 0.7676767706871033
# no_hidden 10 fold 2 iter 1000: Validation accuracy 0.9124578833580017
# no_hidden 10 fold 2 iter 2000: Validation accuracy 0.9158248901367188
#
# no_hidden 10 fold 3 iter 1: Validation accuracy 0.7979797720909119
# no_hidden 10 fold 3 iter 1000: Validation accuracy 0.9292929172515869
# no_hidden 10 fold 3 iter 2000: Validation accuracy 0.932659924030304
#
# no_hidden 10 fold 4 iter 1: Validation accuracy 0.744107723236084
# no_hidden 10 fold 4 iter 1000: Validation accuracy 0.8484848737716675
# no_hidden 10 fold 4 iter 2000: Validation accuracy 0.8417508602142334
#
# no_hidden 10 fold 5 iter 1: Validation accuracy 0.7845118045806885
# no_hidden 10 fold 5 iter 1000: Validation accuracy 0.8989899158477783
# no_hidden 10 fold 5 iter 2000: Validation accuracy 0.9023569226264954
# For hidden 10 , Ending validation accuracy for each fold: [0.8989899, 0.9158249, 0.9326599, 0.84175086, 0.9023569]
# Cross Validation Accuracy 0.898316502571106
#
# no_hidden 15 fold 1 iter 1: Validation accuracy 0.7946127653121948
# no_hidden 15 fold 1 iter 1000: Validation accuracy 0.8922559022903442
# no_hidden 15 fold 1 iter 2000: Validation accuracy 0.9023569226264954
#
# no_hidden 15 fold 2 iter 1: Validation accuracy 0.7575757503509521
# no_hidden 15 fold 2 iter 1000: Validation accuracy 0.8922559022903442
# no_hidden 15 fold 2 iter 2000: Validation accuracy 0.9023569226264954
#
# no_hidden 15 fold 3 iter 1: Validation accuracy 0.7979797720909119
# no_hidden 15 fold 3 iter 1000: Validation accuracy 0.9158248901367188
# no_hidden 15 fold 3 iter 2000: Validation accuracy 0.9023569226264954
#
# no_hidden 15 fold 4 iter 1: Validation accuracy 0.744107723236084
# no_hidden 15 fold 4 iter 1000: Validation accuracy 0.8518518805503845
# no_hidden 15 fold 4 iter 2000: Validation accuracy 0.8619528412818909
#
# no_hidden 15 fold 5 iter 1: Validation accuracy 0.7845118045806885
# no_hidden 15 fold 5 iter 1000: Validation accuracy 0.9057239294052124
# no_hidden 15 fold 5 iter 2000: Validation accuracy 0.8989899158477783
# For hidden 15 , Ending validation accuracy for each fold: [0.9023569, 0.9023569, 0.9023569, 0.86195284, 0.8989899]
# Cross Validation Accuracy 0.893602728843689
#
# no_hidden 20 fold 1 iter 1: Validation accuracy 0.7946127653121948
# no_hidden 20 fold 1 iter 1000: Validation accuracy 0.9057239294052124
# no_hidden 20 fold 1 iter 2000: Validation accuracy 0.9090909361839294
#
# no_hidden 20 fold 2 iter 1: Validation accuracy 0.7575757503509521
# no_hidden 20 fold 2 iter 1000: Validation accuracy 0.9023569226264954
# no_hidden 20 fold 2 iter 2000: Validation accuracy 0.9158248901367188
#
# no_hidden 20 fold 3 iter 1: Validation accuracy 0.7979797720909119
# no_hidden 20 fold 3 iter 1000: Validation accuracy 0.9158248901367188
# no_hidden 20 fold 3 iter 2000: Validation accuracy 0.9158248901367188
#
# no_hidden 20 fold 4 iter 1: Validation accuracy 0.744107723236084
# no_hidden 20 fold 4 iter 1000: Validation accuracy 0.8518518805503845
# no_hidden 20 fold 4 iter 2000: Validation accuracy 0.8619528412818909
#
# no_hidden 20 fold 5 iter 1: Validation accuracy 0.7845118045806885
# no_hidden 20 fold 5 iter 1000: Validation accuracy 0.9057239294052124
# no_hidden 20 fold 5 iter 2000: Validation accuracy 0.9057239294052124
# For hidden 20 , Ending validation accuracy for each fold: [0.90909094, 0.9158249, 0.9158249, 0.86195284, 0.9057239]
# Cross Validation Accuracy 0.901683509349823
#
# no_hidden 25 fold 1 iter 1: Validation accuracy 0.7946127653121948
# no_hidden 25 fold 1 iter 1000: Validation accuracy 0.8888888955116272
# no_hidden 25 fold 1 iter 2000: Validation accuracy 0.8989899158477783
#
# no_hidden 25 fold 2 iter 1: Validation accuracy 0.7575757503509521
# no_hidden 25 fold 2 iter 1000: Validation accuracy 0.9057239294052124
# no_hidden 25 fold 2 iter 2000: Validation accuracy 0.9124578833580017
#
# no_hidden 25 fold 3 iter 1: Validation accuracy 0.7979797720909119
# no_hidden 25 fold 3 iter 1000: Validation accuracy 0.9259259104728699
# no_hidden 25 fold 3 iter 2000: Validation accuracy 0.9528619647026062
#
# no_hidden 25 fold 4 iter 1: Validation accuracy 0.744107723236084
# no_hidden 25 fold 4 iter 1000: Validation accuracy 0.8585858345031738
# no_hidden 25 fold 4 iter 2000: Validation accuracy 0.8619528412818909
#
# no_hidden 25 fold 5 iter 1: Validation accuracy 0.7845118045806885
# no_hidden 25 fold 5 iter 1000: Validation accuracy 0.9090909361839294
# no_hidden 25 fold 5 iter 2000: Validation accuracy 0.9057239294052124
# For hidden 25 , Ending validation accuracy for each fold: [0.8989899, 0.9124579, 0.95286196, 0.86195284, 0.9057239]
# Cross Validation Accuracy 0.9063973426818848
#
# Cross Validation accuracy for each no_hidden: [0.89427614, 0.8983165, 0.8936027, 0.9016835, 0.90639734]

# %%
plt.figure(figsize=(15,5))
plt.title('Comparison of Cross-Validation Accuracy vs. epochs for different number of hidden neurons')
plt.xlabel('epochs')
plt.ylabel('cross-validation accuracy')
plt.xlim(0,2000)
plt.ylim(0.87,0.92)
plt.plot(range(epochs), x_validation_acc[0],'b',label='5 hidden neurons')
plt.plot(range(epochs), x_validation_acc[1],'g',label='10 hidden neurons')
plt.plot(range(epochs), x_validation_acc[2],'r',label='15 hidden neurons')
plt.plot(range(epochs), x_validation_acc[3],'c',label='20 hidden neurons')
plt.plot(range(epochs), x_validation_acc[4],'m',label='25 hidden neurons')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# From the plot titled **comparison of cross-validation accuracy vs. epochs for different batch size** ,we can see that the neural network leveraging on 25 neurons have the best cross-validation accuracy overall, therefore, the optimal number of neurons will be 25.

# %%
N = train_size

u = ffn(x,25)
  
#Cross-entropy
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(labels=y_, logits=u)

#Regularization
regularization = tf.nn.l2_loss(w1) + tf.nn.l2_loss(w2)

#Regularized loss
loss = tf.reduce_mean(cross_entropy + beta*regularization)
  
#Defining the optimiser
optimizer = tf.train.GradientDescentOptimizer(learning_rate)

# Create a variable to track the global step
global_step = tf.Variable(0, name='global_step', trainable=False)

# Use the optimizer to apply the gradients that minimize the loss
# (and also increment the global step counter) as a single training step.
train_op = optimizer.minimize(loss, global_step=global_step)
  
#Evaluate the accuracy and error
correct_prediction = tf.cast(tf.equal(tf.argmax(u, 1), tf.argmax(y_, 1)), tf.float32)
accuracy = tf.reduce_mean(correct_prediction)
error = tf.reduce_sum(tf.cast(tf.not_equal(tf.argmax(u, axis=1), tf.argmax(y_, axis=1)), dtype=tf.int32))

#Running the session
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())
  
  train_acc = []
  test_acc =[]
  
  for i in range(epochs):
    
    for start, end in zip(range(0, N, batch_size), range(batch_size, N, batch_size)):
      train_op.run(feed_dict={x: trainX[start:end], y_: trainY[start:end]})
    
    train_acc.append(accuracy.eval(feed_dict={x: trainX, y_: trainY}))       
    test_acc.append(accuracy.eval(feed_dict={x: testX, y_: testY}))
    
    if i == 0 or (i+1)%1000 == 0:
        print('[iter {}]'.format(i+1))
        print('train accuracy: {}'.format(train_acc[i]))
        print('test accuracy:  {}'.format(test_acc[i]))
        print()
# Out:
# [iter 1]
# train accuracy: 1
# test accuracy:  1
#
# [iter 1000]
# train accuracy: 1000
# test accuracy:  1000
#
# [iter 2000]
# train accuracy: 2000
# test accuracy:  2000

# %%
train_acc
# Out:
# [0.7755376,
#  0.7755376,
#  0.7755376,
#  0.7755376,
#  0.7755376,
#  0.7755376,
#  0.7755376,
#  0.7755376,
#  0.7755376,
#  0.7755376,
#  0.7755376,
#  0.77620965,
#  0.7782258,
#  0.7842742,
#  0.78965056,
#  0.79435486,
#  0.79771507,
#  0.7997312,
#  0.8017473,
#  0.8057796,
#  0.8091398,
#  0.8091398,
#  0.81518817,
#  0.8158602,
#  0.82258064,
#  0.82594085,
#  0.8299731,
#  0.8333333,
#  0.8360215,
#  0.84206986,
#  0.8447581,
#  0.8481183,
#  0.85215056,
#  0.8541667,
#  0.8548387,
#  0.8575269,
#  0.85819894,
#  0.858871,
#  0.859543,
#  0.8608871,
#  0.8635753,
#  0.8635753,
#  0.8655914,
#  0.8655914,
#  0.86491936,
#  0.8669355,
#  0.8682796,
#  0.8689516,
#  0.8689516,
#  0.8689516,
#  0.8716398,
#  0.8736559,
#  0.8729839,
#  0.8729839,
#  0.8736559,
#  0.8736559,
#  0.8729839,
#  0.8736559,
#  0.8736559,
#  0.8736559,
#  0.8729839,
#  0.87432796,
#  0.87432796,
#  0.87432796,
#  0.87432796,
#  0.875,
#  0.87432796,
#  0.875,
#  0.8736559,
#  0.875,
#  0.8763441,
#  0.8763441,
#  0.8770161,
#  0.8797043,
#  0.8797043,
#  0.88037634,
#  0.88037634,
#  0.8810484,
#  0.8817204,
#  0.88239247,
#  0.88239247,
#  0.8817204,
#  0.88239247,
#  0.8817204,
#  0.88239247,
#  0.8830645,
#  0.88373655,
#  0.88508064,
#  0.88508064,
#  0.8857527,
#  0.8857527,
#  0.8877688,
#  0.8877688,
#  0.88844085,
#  0.88844085,
#  0.8891129,
#  0.88844085,
#  0.8891129,
#  0.88978493,
#  0.890457,
#  0.890457,
#  0.890457,
#  0.890457,
#  0.891129,
#  0.891129,
#  0.89180106,
#  0.89180106,
#  0.89180106,
#  0.8944892,
#  0.8951613,
#  0.8938172,
#  0.89314514,
#  0.89314514,
#  0.89314514,
#  0.8924731,
#  0.8924731,
#  0.89314514,
#  0.89314514,
#  0.8924731,
#  0.8924731,
#  0.89314514,
#  0.8924731,
#  0.89314514,
#  0.89314514,
#  0.8924731,
#  0.8924731,
#  0.8924731,
#  0.8938172,
#  0.8938172,
#  0.8938172,
#  0.8944892,
#  0.8951613,
#  0.8958333,
#  0.8958333,
#  0.8958333,
#  0.8958333,
#  0.8958333,
#  0.8958333,
#  0.89650536,
#  0.89650536,
#  0.8958333,
#  0.8958333,
#  0.8958333,
#  0.8958333,
#  0.8958333,
#  0.8958333,
#  0.89650536,
#  0.89650536,
#  0.8971774,
#  0.8971774,
#  0.8971774,
#  0.89784944,
#  0.89784944,
#  0.89784944,
#  0.89784944,
#  0.89784944,
#  0.8985215,
#  0.8991935,
#  0.8991935,
#  0.8991935,
#  0.8991935,
#  0.8991935,
#  0.8991935,
#  0.8991935,
#  0.9005376,
#  0.90120965,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.9005376,
#  0.9005376,
#  0.9005376,
#  0.9005376,
#  0.9005376,
#  0.9005376,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.9005376,
#  0.9005376,
#  0.9005376,
#  0.9005376,
#  0.9005376,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.90120965,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.9018817,
#  0.90255374,
#  0.90255374,
#  0.90255374,
#  0.90255374,
#  0.90255374,
#  0.9032258,
#  0.9032258,
#  0.90255374,
#  0.9032258,
#  0.90255374,
#  0.90255374,
#  0.90255374,
#  0.90255374,
#  0.90255374,
#  0.9032258,
#  0.9032258,
#  0.9032258,
#  0.9032258,
#  0.9032258,
#  0.9032258,
#  0.9032258,
#  0.9032258,
#  0.9032258,
#  0.9032258,
#  0.90255374,
#  0.9032258,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.9038978,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.90456986,
#  0.9052419,
#  0.90456986,
#  0.9052419,
#  0.9052419,
#  0.9052419,
#  0.9052419,
#  0.9052419,
#  0.9052419,
#  0.9052419,
#  0.9052419,
#  0.90591395,
#  0.90591395,
#  0.90591395,
#  0.90591395,
#  0.90591395,
#  0.90591395,
#  0.90591395,
#  0.90591395,
#  0.90591395,
#  0.9072581,
#  0.90658605,
#  0.90658605,
#  0.90658605,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.90793014,
#  0.9072581,
#  0.9072581,
#  0.90793014,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.9072581,
#  0.90793014,
#  0.90793014,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9086022,
#  0.9092742,
#  0.9086022,
#  0.9092742,
#  0.9092742,
#  0.9092742,
#  0.9092742,
#  0.9092742,
#  0.9092742,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.9092742,
#  0.90994626,
#  0.9106183,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.90994626,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.91129035,
#  0.9106183,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.91129035,
#  0.9119624,
#  0.91129035,
#  0.91129035,
#  0.9119624,
#  0.91263443,
#  0.91263443,
#  0.9119624,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.9119624,
#  0.91263443,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.9119624,
#  0.91263443,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.91129035,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.9106183,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.9106183,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.91129035,
#  0.9119624,
#  0.91129035,
#  0.9119624,
#  0.9119624,
#  0.91129035,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.91263443,
#  0.9119624,
#  0.9119624,
#  0.9119624,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.91263443,
#  0.9133065,
#  0.9133065,
#  0.9133065,
#  0.9133065,
#  0.9139785,
#  0.9133065,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.91465056,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.91465056,
#  0.9139785,
#  0.9139785,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.91465056,
#  0.9153226,
#  0.91465056,
#  0.9153226,
#  0.91465056,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.91465056,
#  0.9153226,
#  0.91599464,
#  0.91599464,
#  0.91465056,
#  0.9153226,
#  0.91599464,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.91599464,
#  0.9153226,
#  0.9153226,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.9139785,
#  0.91465056,
#  0.91465056,
#  0.9139785,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.91465056,
#  0.9153226,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.91599464,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9166667,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9173387,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9173387,
#  0.9166667,
#  0.9166667,
#  0.9173387,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9153226,
#  0.91599464,
#  0.91599464,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.9153226,
#  0.91599464,
#  0.9153226,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9166667,
#  0.9173387,
#  0.9166667,
#  0.9173387,
#  0.9180108,
#  0.9186828,
#  0.9180108,
#  0.9180108,
#  0.9180108,
#  0.9186828,
#  0.9186828,
#  0.9180108,
#  0.9180108,
#  0.9180108,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9180108,
#  0.9186828,
#  0.9180108,
#  0.9180108,
#  0.9186828,
#  0.9180108,
#  0.9180108,
#  0.9180108,
#  0.9180108,
#  0.9186828,
#  0.9180108,
#  0.9180108,
#  0.9180108,
#  0.9180108,
#  0.9186828,
#  0.9180108,
#  0.9186828,
#  0.9180108,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.91935486,
#  0.91935486,
#  0.9186828,
#  0.91935486,
#  0.9186828,
#  0.91935486,
#  0.9186828,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.91935486,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9186828,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.92069894,
#  0.9200269,
#  0.92069894,
#  0.92069894,
#  0.9200269,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.9200269,
#  0.92069894,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.92069894,
#  0.9200269,
#  0.9200269,
#  0.9200269,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.921371,
#  0.92069894,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.92069894,
#  0.9200269,
#  0.92069894,
#  0.921371,
#  0.921371,
#  0.92069894,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.922043,
#  0.921371,
#  0.921371,
#  0.921371,
#  0.922043,
#  0.921371,
#  0.922043,
#  0.922043,
#  0.922043,
#  0.922043,
#  0.921371,
#  0.922043,
#  0.921371,
#  0.922043,
#  0.922043,
#  ...]

# %%
# plot learning curves
plt.figure()
plt.title('Accuracy vs. epochs')
plt.plot(range(epochs), train_acc,'g',label='train')
plt.plot(range(epochs), test_acc,'r',label='test')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend(loc='best')
plt.show()
